# %% [markdown]
# # 反爬：瀏覽器標頭與基本資訊
#
#
# * 了解「檢查 HTTP 標頭檔」的反爬蟲機制
# * 「檢查 HTTP 標頭檔」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）
# * 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %% [markdown]
# ### 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）

# %%
import requests
from bs4 import BeautifulSoup

url = "https://whatismyipaddress.com/"

headers ={
'user-agent':"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36 Edg/84.0.522.40"
}

resp = requests.get(url)
soup = BeautifulSoup(resp.text,"lxml")
print(soup.text)
#print(len(resp.text))
#print(resp.text)
# Out:
# Access Denied (BUA77). Contact support@whatismyipaddress.com

# %%
resp2= requests.get(url,headers=headers)
soup2 = BeautifulSoup(resp2.text,"lxml")
print(soup2.text)
print(len(resp2.text))
#print(resp2.text)
# Out:
# What Is My IP Address - See Your Public Address - IPv4 & IPv6
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# About | Press | Contact
#
#
#
#
#
#
#
# MY IP
# IP LOOKUP
# HIDE MY IP
#
# VPNS
#
#
# What is a VPN
# Why Use a VPN
# Choosing a VPN
# VPN Comparison
# Free VPNs
# VPN Reviews
# VPNs for Torrenting
# VPNs for Streaming
#
#
#
# TOOLS
#
#
# IP Lookup
# Blacklist Check
# Breach Check
# Proxy Check
# VPN Leak Check
# Trace Email
# Speed Test
# Reverse DNS Lookup
# Hostname Lookup
#
#
#
# LEARN
#
#
# Online Safety
# Hackers and Hoaxes
# Privacy
# IP Addresses
#
#
#
#
#
#
#
#
#
# IP LookupKnow the IP address of another computer? You can find where in the world it is—and more.
#
#
#
# Trace EmailTrack down the geographical location and origin of an email you received.
#
#
#
# Hide My IPLearn how to use a high-tech "middleman" to shield your realIP address on the Internet.
#
#
#
# VPN ComparisonCompare top rated VPN service providers that meet your needs and budget.
#
#
#
# Blacklist CheckHave you been blacklisted because of the IP address you use? Check to see here.
#
#
#
# Speed TestIs your Internet connection up to speed? Find out for free with a quick click.
#
#
#
# IP ToolsHave the right tool for any job. That goes for your Internet connection, too.
#
#
#
#
#
#
# This site is 100% ad supported.Please consider enabling JavaScript so that we can support continued development.
#
#
#
#
# My IP Address Is:
#
#
# IPv4: 61.223.126.116
#
# IPv6:
#
#
#
#
# My IP Information:
#
#
# ISP:HiNet
# City:Chang-hua
# Region:Changhua
# Country:Taiwan
#
# Make My IP Address PrivateClick Here
#
# Javascript disabled or geolocation map not available.
#
#
#
# Location not accurate? Update my IP location Show Complete IP Details
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Which is your biggest concern about using the Internet:
#
# SecurityI want protection from hackerson public Wi-Fi and otherunsecured networks.
# PrivacyI want to prevent my government,ISP and advertisers fromtracking me.
# AccessI want to access Netflix, Hulu,and other streaming serviceswithout being blocked.
#
#
#
#
#
#
#
#
#
# Recent Articles
#
#
#
#
#
# Listen to the Easy Prey Podcast
#
#
#
#
#
# Private Browsing
#
#
#
# Stimulus Check Scams
#
#
#
# 5 Online Privacy Tips
#
#
#
# Saving with a VPN
#
#
#
# Free VPNs
#
#
#
# VPN Reviews
#
#
#
# Mon IP |
# 						Meine IP |
# 						Mi IP |
# 						IP'im |
# 						MÃ³je IP |
# 						æç IP
#
#
#
#
#
#
#
#
#
# © 2000-2020 What Is My IP Address. All Rights Reserved.
#
#
# Privacy Policy
# Terms of Use
# Media
# Community
# About
# Contact
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 32056

# %% [markdown]
# ### 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %%
"""
從開發者工具的Network下，看到 在Request Headers底下：
:authority: whatismyipaddress.com
:method: GET
:path: /
:scheme: https
accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9
accept-encoding: gzip, deflate, br
accept-language: en-TW,en-US;q=0.9,en;q=0.8,zh-TW;q=0.7,zh;q=0.6
cache-control: max-age=0
cookie: _fsuid=72542e42-894d-492b-8248-b38b674a787f; __cfduid=d7a3dcbc6a0ae8b0a7b5a99b1604903d41593676644; _fsloc=?i=US&c=San Jose; pt=79fbbc27b8c2087cba45e84ec657b177; fsbotchecked=true; _fssid=c748c549-6771-4586-8e9b-a7c97773024d; fssts=false
dnt: 1
sec-fetch-dest: document
sec-fetch-mode: navigate
sec-fetch-site: none
sec-fetch-user: ?1
upgrade-insecure-requests: 1
user-agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36 Edg/84.0.522.40
"""

#經測試只要加上user-agent就可以成功訪問網頁
# Out:
# '\nYour Code Here\n'
